# %%
import pandas as pd
import pickle

# henter vores dataframe (document-term), hvor vores definerede stopwords er sorteret fra
data = pd.read_pickle('dtm_stop.pkl')
data
# Out:
#             aaron  abandon  abandoned  abandoning  abandonment  abhorrent  \
# bushjunior      0        1          0           0            0          0
# bushsenior      0        0          0           0            0          0
# carter          0        1          1           0            0          1
# clinton         2        0          0           0            0          0
# johnson         0        0          0           0            0          0
# kennedy         0        1          0           0            1          0
# nixon           0        0          0           1            0          0
# obama           0        0          0           0            0          0
# reagan          0        0          0           0            0          0
# trump           0        0          0           0            0          0
#
#             ability  abject  able  ablebodied  ...    young  youre  youth  \
# bushjunior        4       0     0           0  ...        2      0      0
# bushsenior        0       0     0           1  ...        0      1      0
# carter            2       0     0           0  ...        2      0      1
# clinton           1       0     4           0  ...        9      1      0
# johnson           0       0    10           0  ...        2      0      0
# kennedy           4       0     0           0  ...        3      0      2
# nixon             1       0     4           0  ...        2      0      1
# obama             0       0     1           0  ...        3      0      0
# reagan            0       0     0           0  ...        5      0      0
# trump             0       1     3           0  ...        5      0      0
#
#             youthful  youve  zeitchik  zero  zimbabwe  zone  zones
# bushjunior         0      0         0     0         1     0      0
# bushsenior         0      0         0     0         0     1      0
# carter             0      0         0     0         0     0      0
# clinton            0      0         0     0         0     0      1
# johnson            0      0         0     0         0     0      0
# kennedy            1      0         0     0         0     0      0
# nixon              0      0         0     1         0     0      0
# obama              0      1         0     0         0     0      0
# reagan             0      0         0     0         0     0      0
# trump              0      0         2     0         0     0      0
#
# [10 rows x 5519 columns]

# %%
from gensim import matutils, models
import scipy.sparse

# For at lave Topic Modeling, skal vi bruge formatet term-document, så vi 'vender' vores df
tdm = data.transpose()
tdm.head()
# Out:
#              bushjunior  bushsenior  carter  clinton  johnson  kennedy  nixon  \
# aaron                 0           0       0        2        0        0      0
# abandon               1           0       1        0        0        1      0
# abandoned             0           0       1        0        0        0      0
# abandoning            0           0       0        0        0        0      1
# abandonment           0           0       0        0        0        1      0
#
#              obama  reagan  trump
# aaron            0       0      0
# abandon          0       0      0
# abandoned        0       0      0
# abandoning       0       0      0
# abandonment      0       0      0

# %%
# Uforståelig del - check op på hvad der foregår her

# We're going to put the term-document matrix into a new gensim format, from df --> sparse matrix --> gensim corpus
sparse_counts = scipy.sparse.csr_matrix(tdm)
corpus = matutils.Sparse2Corpus(sparse_counts)
# Out:
# <5519x10 sparse matrix of type '<class 'numpy.int64'>'
# 	with 11903 stored elements in Compressed Sparse Row format>

# %%
# Gensim also requires dictionary of the all terms and their respective location in the term-document matrix
cv = pickle.load(open("cv_stop.pkl", "rb"))
id2word = dict((v, k) for k, v in cv.vocabulary_.items())

# %%
# Now that we have the corpus (term-document matrix) and id2word (dictionary of location: term),
# we need to specify two other parameters as well - the number of topics and the number of passes
lda = models.LdaModel(corpus=corpus, id2word=id2word, num_topics=3, passes=30)
lda.print_topics()
# Out:
# [(0,
#   '0.009*"peace" + 0.007*"nations" + 0.005*"soviet" + 0.004*"union" + 0.004*"energy" + 0.004*"free" + 0.004*"great" + 0.003*"defense" + 0.003*"military" + 0.003*"security"'),
#  (1,
#   '0.005*"work" + 0.004*"children" + 0.003*"future" + 0.003*"government" + 0.003*"economy" + 0.003*"tax" + 0.003*"freedom" + 0.003*"pass" + 0.003*"health" + 0.003*"care"'),
#  (2,
#   '0.005*"peace" + 0.004*"great" + 0.004*"nations" + 0.004*"budget" + 0.004*"commitments" + 0.004*"vietnam" + 0.004*"act" + 0.003*"increase" + 0.003*"administration" + 0.003*"public"')]
